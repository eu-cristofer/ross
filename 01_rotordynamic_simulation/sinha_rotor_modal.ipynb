# %%
import numpy as np
import ross as rs
from ross.materials import Material

# Make sure the default renderer is set to 'notebook' for inline plots in Jupyter
import plotly.io as pio

pio.renderers.default = "notebook"

print(f"ROSS version: {rs.__version__}")

Q_ = rs.Q_

rotor = rs.Rotor.load("sinha_rotor.toml")
# Out:
# ROSS version: 2.1.0

# %%
modal = rotor.run_modal(speed=Q_(100, "rad/s"), num_modes=12)

print("\nUndamped natural frequencies (Hz):")
print((modal.wn / (2 * np.pi)))

print("\nDamped natural frequencies (Hz):")
print((modal.wd / (2 * np.pi)))

print("\nDamping ratios:")
print(modal.damping_ratio)
# Out:
# Undamped natural frequencies (Hz):
# [ 27.49963612  27.50036394 132.59745578 134.29498271 187.53609847
#  187.67372809]
#
# Damped natural frequencies (Hz):
# [ 27.49168139  27.49240729 124.53089847 125.90276145 174.95427467
#  175.01319714]
#
# Damping ratios:
# [0.02405098 0.02405357 0.34346612 0.34796089 0.36010998 0.36106752]

# %%
modal.plot_mode_3d(mode=1, frequency_units="Hz")
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="a495a2f4-7050-44c2-8e29-45d73bea154a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("a495a2f4-7050-44c2-8e29-45d73bea154a")) {                    Plotly.newPlot(                        "a495a2f4-7050-44c2-8e29-45d73bea154a",                        [{"hovertemplate":"Nodal Position: %{x:.2f}\u003cbr\u003eX - Displacement: %{y:.2f}\u003cbr\u003eY - Displacement: %{z:.2f}","marker":{"color":"#1f77b4"},"mode":"markers","name":"node 0","showlegend":false,"x":[0.0],"y":[0.0371535029231913],"z":[0.20192483691709068],"type":"scatter3d"},{"hovertemplate":"Nodal Position: %{x:.2f}\u003cbr\u003eX - Displacement: %{y:.2f}\u003cbr\u003eY - Displacement: %{z:.2f}","line":{"color":"#1f77b4"},"mode":"lines","name":"node 0","showlegend":false,"x":{"dtype":"f8","bdata":"..."},"y":{"dtype":"f8","bdata":"H1H5r8gFoz\u002fmIb0Y2DWhP1de1AocyZ4\u002fTlKw5B0kmz+EWzPo\u002fnyXP0frO2kI1JM\u002f6Kih4IMpkD8SGOXMdfuIP5gIW1juoYE\u002faIns2wmOdD9gY0ueaVpXP+BIrX+UwmG\u002f0OCepHyYd780oIev6iaDv9zRSpYWgIq\u002fFOK6QZfrkL\u002f0G86Oz5WUv9JuS6BqPpi\u002fHouGBB\u002flm79Uz\u002fxvo4mfv8JPimHXlaG\u002f36XsB3xlo7\u002fNiNlPmzOlv0tjjfwQAKe\u002fR1yk8rjKqL8fKe86b5OqvxgJRQUQWqy\u002fgrFSq3cerr\u002fu8WWzguCvv07smukG0LC\u002fio9T+Xqusb\u002fNU0YXjIuyv+rpse0oZ7O\u002fJD8GREBBtL\u002fVLz4AwRm1v+\u002fUNiia8LW\u002fh1EE47rFtr+QBUR6Epm3vzwLbFuQari\u002f8+QXGSQ6ub9fQVJsvQe6vyu82zVM07q\u002fZ4Fuf8Ccu793uv58CmS8v2Gr940aKb2\u002fhGd1PuHrvb8fBXtIT6y+v5o3JZVVar+\u002f\u002f5vsnvISwL8\u002f8rfGd2\u002fAv4d\u002frgCzysC\u002fHTppJZ0kwb+sye8nL33Bv6kQRhZi1MG\u002fGJj3GS8qwr+o0qB4j37Cv18sdpR80cK\u002fUNzI7O8iw7\u002fjbYke43LDv3T3x+RPwcO\u002fTvQxGTAOx