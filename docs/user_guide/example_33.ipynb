# %% [markdown]
# # Example 33 - Sinha Stepwise Numerical Replication
#
# This example points to the learning workflow in `01_rotordynamic_simulation`.
#
# Main integrated notebook:
# - `01_rotordynamic_simulation/sinha_pipeline_step_by_step.ipynb`
#
# Step scripts:
# - `step_01_geometry_and_units.py`
# - `step_02_build_healthy_rotor.py`
# - `step_03_modal_calibration_27_5hz.py`
# - `step_04_fault_runs_crack_misalignment.py`
# - `step_05_hos_analysis.py`
# - `step_06_compare_with_sinha.py`

# %%
import runpy
from pathlib import Path

base = Path("01_rotordynamic_simulation")
runpy.run_path(base / "step_01_geometry_and_units.py", run_name="__main__")
